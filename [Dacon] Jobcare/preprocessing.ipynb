# %% [markdown]
# # HappyNewYear님 & -_-님 코드 참조

# %%
from typing import Dict
import numpy as np
import pandas as pd
from datetime import datetime

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline

# %%
def add_code(
    df: pd.DataFrame,
    d_code: Dict[int, Dict[str, int]], 
    h_code: Dict[int, Dict[str, int]], 
    l_code: Dict[int, Dict[str, int]],
) -> pd.DataFrame:
    
    # Copy input data
    df = df.copy()   

    # D Code
    df['person_prefer_d_1_n'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_1_s'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_1_m'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_1_l'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_2_n'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_2_s'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_2_m'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_2_l'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_3_n'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_3_s'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_3_m'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_3_l'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['contents_attribute_d_n'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['contents_attribute_d_s'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['contents_attribute_d_m'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['contents_attribute_d_l'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    # H Code
    df['person_prefer_h_1_l'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_1_m'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    
    df['person_prefer_h_2_l'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_2_m'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    
    df['person_prefer_h_3_l'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_3_m'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

    df['contents_attribute_h_l'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['contents_attribute_h_m'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

    # L Code
    df['contents_attribute_l_n'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 세분류코드'])
    df['contents_attribute_l_s'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 소분류코드'])
    df['contents_attribute_l_m'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 중분류코드'])
    df['contents_attribute_l_l'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 대분류코드'])
    
    return df

# %%
df_train = pd.read_csv('./drive/MyDrive/Dacon/jobcare/data/train.csv')
df_test = pd.read_csv('./drive/MyDrive/Dacon/jobcare/data/test.csv')

# %% [markdown]
# # label encoding

# %%
d_code = pd.read_csv('./drive/MyDrive/Dacon/jobcare/data/속성_D_코드.csv', index_col=0)
h_code = pd.read_csv('./drive/MyDrive/Dacon/jobcare/data/속성_H_코드.csv', index_col=0)
l_code = pd.read_csv('./drive/MyDrive/Dacon/jobcare/data/속성_L_코드.csv', index_col=0)

# %%
d_code = d_code.T.to_dict()
h_code = h_code.T.to_dict()
l_code = l_code.T.to_dict()

# %%
df_train = add_code(df_train, d_code, h_code, l_code)
df_test = add_code(df_test, d_code, h_code, l_code)

# %%
df_train["d_l_match_yn"] = df_train["d_l_match_yn"].astype(int)
df_train["d_m_match_yn"] = df_train["d_m_match_yn"].astype(int)
df_train["d_s_match_yn"] = df_train["d_s_match_yn"].astype(int)
df_train["h_l_match_yn"] = df_train["h_l_match_yn"].astype(int)
df_train["h_m_match_yn"] = df_train["h_m_match_yn"].astype(int)
df_train["h_s_match_yn"] = df_train["h_s_match_yn"].astype(int)

# %%
df_test["d_l_match_yn"] = df_test["d_l_match_yn"].astype(int)
df_test["d_m_match_yn"] = df_test["d_m_match_yn"].astype(int)
df_test["d_s_match_yn"] = df_test["d_s_match_yn"].astype(int)
df_test["h_l_match_yn"] = df_test["h_l_match_yn"].astype(int)
df_test["h_m_match_yn"] = df_test["h_m_match_yn"].astype(int)
df_test["h_s_match_yn"] = df_test["h_s_match_yn"].astype(int)

# %% [markdown]
# * 'person_prefer_f', 'person_prefer_g', 'Y': cardinality가 1인 변수
# * 'person_rn', 'contents_rn': 고유 값으로 보고 삭제
# *

# %% [markdown]
# # ========================================

# %%
df_train.loc[:,['d_l_match_yn', 'person_prefer_d_1_l', 'contents_attribute_d_l']]

# %%
# len(df_train[(df_train['d_l_match_yn']==1) & (df_train['d_m_match_yn']==1) & (df_train['d_s_match_yn']==1) & (df_train['h_l_match_yn']==1) & (df_train['h_m_match_yn']==1) & (df_train['h_s_match_yn']==1) & (df_train['target']==0)])
# len(df_train[(df_train['d_l_match_yn']==1) & (df_train['d_m_match_yn']==1) & (df_train['d_s_match_yn']==1) & (df_train['h_l_match_yn']==1) & (df_train['h_m_match_yn']==1) & (df_train['h_s_match_yn']==1) & (df_train['target']==1)])

# %%
df_train['matching_num'] = df_train['d_l_match_yn'] + df_train['d_m_match_yn'] + df_train['d_s_match_yn'] + df_train['h_l_match_yn'] + df_train['h_m_match_yn'] + df_train['h_s_match_yn']
df_test['matching_num'] = df_test['d_l_match_yn'] + df_test['d_m_match_yn'] + df_test['d_s_match_yn'] + df_test['h_l_match_yn'] + df_test['h_m_match_yn'] + df_test['h_s_match_yn']

# %%
df_train.matching_num.unique()

# %%
for i in set(df_train.matching_num.unique()):
    zero = len(df_train[(df_train['matching_num']==i) & (df_train['target']==0)])
    one = len(df_train[(df_train['matching_num']==i) & (df_train['target']==1)])
    percent = one/(zero+one) * 100
    print(f'matching number: {i}, target 0: {zero}, target 1: {one}, percent: {percent}%')

# %%
scaler = StandardScaler()
df_train['matching_num'] = scaler.fit_transform(df_train['matching_num'].values.reshape(-1,1))
df_test['matching_num'] = scaler.fit_transform(df_test['matching_num'].values.reshape(-1,1))

# %% [markdown]
# # ========================================

# %%
df_train = df_train.drop(['id', 'person_prefer_f', 'person_prefer_g', 'contents_open_dt', 'person_rn', 'contents_rn'], axis=1)
df_train

# %%
df_test = df_test.drop(['id', 'person_prefer_f', 'person_prefer_g', 'contents_open_dt', 'person_rn', 'contents_rn'], axis=1)
df_test

# %%
df_train.to_csv('./drive/MyDrive/Dacon/jobcare/data/train_pp.csv', index = False)
df_test.to_csv('./drive/MyDrive/Dacon/jobcare/data/test_pp.csv', index = False)
